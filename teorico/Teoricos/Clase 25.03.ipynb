# %%
bitstring(Int16(3247))
# Out:
# "0000110010101111"

# %%
bitstring(Int8(2^7-1))
# Out:
# "01111111"

# %%
bitstring(Int8(-2^7))
# Out:
# "10000000"

# %%
bitstring(1.)
# Out:
# "0011111111110000000000000000000000000000000000000000000000000000"

# %%
bitstring(-2^63-1)
# Out:
# "0111111111111111111111111111111111111111111111111111111111111111"

# %%
π
# Out:
# π = 3.1415926535897...

# %%
ℯ
# Out:
# ℯ = 2.7182818284590...

# %%
bitstring(Float16(π))
# Out:
# "0100001001001000"

# %%
π
# Out:
# π = 3.1415926535897...

# %%
eps(1.)
# Out:
# 2.220446049250313e-16

# %%
using Plots

# %%
x = -40:0.1:40
y = x.^2
# Out:
# 801-element Array{Float64,1}:
#  1600.0
#  1592.01
#  1584.0399999999997
#  1576.0900000000001
#  1568.16
#  1560.25
#  1552.36
#  1544.4899999999998
#  1536.6400000000003
#  1528.8100000000002
#  1521.0
#  1513.2099999999998
#  1505.4399999999998
#     ⋮
#  1513.2099999999998
#  1521.0
#  1528.8100000000002
#  1536.6400000000003
#  1544.4899999999998
#  1552.36
#  1560.25
#  1568.16
#  1576.0900000000001
#  1584.0399999999997
#  1592.01
#  1600.0

# %%
scatter(x,y)

# %%
N = 100
xx = zeros(N)
yy = zeros(N)

for i ∈ 1:N
    xx[i] = i
    yy[i] = sin(2*π*i/N)
end
scatter(xx,yy)

# %%
a = Array{Float64,2}(undef,(50,20))
# Out:
# 50×20 Array{Float64,2}:
#    0.0             6.9033e-310   …  0.0             0.0
#    4.52169e-316    1.0e-323         4.55613e-316    4.2095e-316
#    4.20913e-316    0.0              4.20943e-316    4.43692e-316
#    4.20915e-316  NaN                4.20949e-316    6.9033e-310
#  NaN             NaN                0.0             4.40439e-316
#    4.52169e-316    0.0           …  0.0             4.20952e-316
#    4.52132e-316    6.9033e-310      1.01856e-312    6.36599e-314
#    4.20915e-316    4.20914e-316     4.20949e-316    4.2095e-316
#    6.9033e-310     4.20917e-316     0.0             4.43624e-316
#  NaN             NaN                0.0             4.55613e-316
#    0.0             4.40439e-316  …  4.20944e-316    2.75926e-312
#  NaN               4.20916e-316     4.20951e-316    4.20951e-316
#    0.0             6.89967e-310     6.9033e-310     4.20935e-316
#    ⋮                             ⋱
#    4.20914e-316    4.52156e-316     0.0           NaN
# ...

# %%
v = Array{Float64,1}(undef,30)
# Out:
# 30-element Array{Float64,1}:
#  8.0e-323
#  8.0e-323
#  6.90323088951863e-310
#  6.9032308895226e-310
#  8.4e-323
#  8.4e-323
#  6.90323088952653e-310
#  6.9032308895305e-310
#  9.0e-323
#  9.0e-323
#  6.90323088953444e-310
#  6.9032308895384e-310
#  9.4e-323
#  ⋮
#  6.90323088955025e-310
#  6.9032308895542e-310
#  1.63e-322
#  1.7e-322
#  6.9032308895621e-310
#  6.90323088957e-310
#  1.73e-322
#  1.8e-322
#  6.90323088957396e-310
#  6.9032308895779e-310
#  1.83e-322
#  1.83e-322
